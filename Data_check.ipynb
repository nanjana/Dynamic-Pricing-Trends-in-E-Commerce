# %% [markdown]
# ## Kaggle dataset

# %%
import pandas as pd
df_hist = pd.read_csv("2019-Nov.csv")

# %%
import pandas as pd

# List of desired categories
categories_to_extract = [
    "electronics.audio.headphone",
    "electronics.smartphone",
    "electronics.tablet"
]

# Filter the DataFrame based on the category_code column
filtered_df = df_hist[df_hist['category_code'].isin(categories_to_extract)]

# Display the filtered DataFrame
print(filtered_df)

# Save to a CSV if needed
#filtered_df.to_csv('filtered_data.csv', index=False)
# Out:
#                        event_time event_type  product_id          category_id  \
# 0         2019-11-01 00:00:00 UTC       view     1003461  2053013555631882655
# 4         2019-11-01 00:00:01 UTC       view     1004775  2053013555631882655
# 9         2019-11-01 00:00:02 UTC       view     1004258  2053013555631882655
# 18        2019-11-01 00:00:07 UTC       view     1004566  2053013555631882655
# 21        2019-11-01 00:00:08 UTC       view     1004708  2053013555631882655
# ...                           ...        ...         ...                  ...
# 67501965  2019-11-30 23:59:53 UTC       view     4804294  2053013554658804075
# 67501966  2019-11-30 23:59:54 UTC       view     1005174  2053013555631882655
# 67501967  2019-11-30 23:59:54 UTC       view     1005118  2053013555631882655
# 67501976  2019-11-30 23:59:59 UTC       view     1004833  2053013555631882655
# 67501978  2019-11-30 23:59:59 UTC       view     1004233  2053013555631882655
#
#                         category_code    brand    price    user_id  \
# 0              electronics.smartphone   xiaomi   489.07  520088904
# 4              electronics.smartphone   xiaomi   183.27  558856683
# 9              electronics.smartphone    apple   732.07  532647354
# 18             electronics.smartphone   huawei   164.84  566265908
# 21             electronics.smartphone   huawei   151.99  566143627
# ...                               ...      ...      ...        ...
# 67501965  electronics.audio.headphone    meizu    64.09  513558661
# 67501966       electronics.smartphone  samsung   591.75  579969525
# 67501967       electronics.smartphone    apple   925.47  579969045
# 67501976       electronics.smartphone  samsung   167.03  557794415
# 67501978       electronics.smartphone    apple  1312.52  579969851
#
#                                   user_session
# 0         4d3b30da-a5e4-49df-b1a8-ba5943f1dd33
# 4         313628f1-68b8-460d-84f6-cec7a8796ef2
# 9         d2d3d2c6-631d-489e-9fb5-06f340b85be0
# 18        52c2c76c-b79e-4794-86ff-badc76d35f5a
# 21        aa610ab3-5c60-4551-8a2b-8c999dddf843
# ...                                        ...
# 67501965  378e7ed4-649a-4302-b917-b953da5ee801
# 67501966  180a7f1f-ed0c-485a-b145-a980716d6abb
# 67501967  ee246970-62cb-4105-a049-703cdaee3a26
# 67501976  6fecf566-ebb0-4e70-a243-cdc13ce044cb
# 67501978  90aca71c-ed8a-4670-866a-761ebacb732d
#
# [18684374 rows x 9 columns]

# %%
filtered_df['brand'].unique()
# Out:
# array(['xiaomi', 'apple', 'huawei', 'acme', 'samsung', 'oppo', 'hp',
#        'steelseries', 'oneplus', 'irbis', 'vivo', 'nokia', 'meizu',
#        'lenovo', 'honor', 'tp-link', 'elari', 'zte', 'harper', 'sony',
#        'acer', 'lg', 'usams', 'bq', 'htc', 'blackberry', 'jbl', 'hyperx',
#        'vertex', 'google', nan, 'sennheiser', 'bose', 'huion', 'wacom',
#        'kingston', 'prestigio', 'parrot', 'haier', 'razer', 'inoi',
#        'jinga', 'doogee', 'nubia', 'creative', 'defender', 'beats',
#        'texet', 'marshall', 'panasonic', 'olmio', 'microsoft', 'asus',
#        'urbanears', 'awei', 'umi', 'fly', 'nexttab', 'jabra', 'koss',
#        'olto', 'edifier', 'plantronics', 'beyerdynamic', 'tecno',
#        'canyon', 'philips', 'trust', 'ritmix', 'genius', 'zalman', 'sven',
#        'microlab', 'gionee', 'cnd', 'oukitel', 'orico', 'denn',
#        'redragon', 'crown', 'audio-technica', 'krk', 'continent',
#        'fender', 'wuw', 'leeco', 'inkax', 'micromax', 'xp-pen', 'pioneer',
#        'presonus', 'hoco', 'global', 'marley', 'manhattan', 'fiio',
#        'veho', 'bluedio', 'fostex', 'logitech', 'alctron', 'ipipoo',
#        'qcyber', 'havit', 'leagoo', 'akg', 'ergo', 'joyroom', 'navitel',
#        'jvc', 'yamaha', 'gamemax', 'shure', 'hercules', 'rapoo', 'roland',
#        'intro', 'westone', 'rombica', 'nuforce', 'monster', 'vox',
#        'magnat', 'soundking', 'gigabyte', 'remax', 'cowon', 'elenberg',
#        'alesis', 'behringer', 'numark', 'hiper', 'acqua', 'superlux',
#        'delux', 'ultrasone', 'msi', 'tascam', 'hifiman', 'dunu', 'meze',
#        'g-cube', 'ark', 'samson', 'nomi', 'proel', 'siee', 'casio',
#        'm-audio', 'tesoro', 'avermedia', 'celebrat', 'skullcandy',
#        'gembird', 'sades', 'kalenji', 'borasco', 'nobby', 'gamdias',
#        'motorola', 'cougar', 'aula', 'bravis', 'yison', 'mark', 'iwalk',
#        'invotone', 'moxom'], dtype=object)

# %% [markdown]
# ## Ebay dataset

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import pandas as pd

# Set up Selenium WebDriver
driver = webdriver.Chrome()  

categories = ['smartphone', 'headphone', 'tablet']
base_url = "https://www.ebay.com/sch/i.html?_nkw="
category_limit = 5000  # Limit per category

products = []

# List of known brands for cleaning
known_brands = ['xiaomi', 'apple', 'huawei', 'acme', 'samsung', 'oppo', 'hp',
       'steelseries', 'oneplus', 'irbis', 'vivo', 'nokia', 'meizu',
       'lenovo', 'honor', 'tp-link', 'elari', 'zte', 'harper', 'sony',
       'acer', 'lg', 'usams', 'bq', 'htc', 'blackberry', 'jbl', 'hyperx',
       'vertex', 'google', 'sennheiser', 'bose', 'huion', 'wacom',
       'kingston', 'prestigio', 'parrot', 'haier', 'razer', 'inoi',
       'jinga', 'doogee', 'nubia', 'creative', 'defender', 'beats',
       'texet', 'marshall', 'panasonic', 'olmio', 'microsoft', 'asus',
       'urbanears', 'awei', 'umi', 'fly', 'nexttab', 'jabra', 'koss',
       'olto', 'edifier', 'plantronics', 'beyerdynamic', 'tecno',
       'canyon', 'philips', 'trust', 'ritmix', 'genius', 'zalman', 'sven',
       'microlab', 'gionee', 'cnd', 'oukitel', 'orico', 'denn',
       'redragon', 'crown', 'audio-technica', 'krk', 'continent',
       'fender', 'wuw', 'leeco', 'inkax', 'micromax', 'xp-pen', 'pioneer',
       'presonus', 'hoco', 'global', 'marley', 'manhattan', 'fiio',
       'veho', 'bluedio', 'fostex', 'logitech', 'alctron', 'ipipoo',
       'qcyber', 'havit', 'leagoo', 'akg', 'ergo', 'joyroom', 'navitel',
       'jvc', 'yamaha', 'gamemax', 'shure', 'hercules', 'rapoo', 'roland',
       'intro', 'westone', 'rombica', 'nuforce', 'monster', 'vox',
       'magnat', 'soundking', 'gigabyte', 'remax', 'cowon', 'elenberg',
       'alesis', 'behringer', 'numark', 'hiper', 'acqua', 'superlux',
       'delux', 'ultrasone', 'msi', 'tascam', 'hifiman', 'dunu', 'meze',
       'g-cube', 'ark', 'samson', 'nomi', 'proel', 'siee', 'casio',
       'm-audio', 'tesoro', 'avermedia', 'celebrat', 'skullcandy',
       'gembird', 'sades', 'kalenji', 'borasco', 'nobby', 'gamdias',
       'motorola', 'cougar', 'aula', 'bravis', 'yison', 'mark', 'iwalk',
       'invotone', 'moxom']

# Iterate over categories to scrape data
for category in categories:
    print(f"Scraping data for category: {category}")
    page = 1
    category_records = []  # Temporary list for the current category
    
    while len(category_records) < category_limit:
        # Generate the URL for the current page and category
        url = f"{base_url}{category}&_pgn={page}"
        driver.get(url)
        print(f"Scraping URL: {url}")
        
        # Extract product details
        items = driver.find_elements(By.CLASS_NAME, 's-item')
        
        if not items:
            print(f"No more items found for {category}. Ending scraping for this category.")
            break
        
        for item in items:
            try:
                product_id = item.get_attribute('id')  # Retrieve Product ID if available
                title = item.find_element(By.CLASS_NAME, 's-item__title').text
                price = item.find_element(By.CLASS_NAME, 's-item__price').text
                shipping_price = item.find_element(By.CLASS_NAME, 's-item__shipping').text if item.find_elements(By.CLASS_NAME, 's-item__shipping') else "Free Shipping"
                brand = item.find_element(By.CLASS_NAME, 's-item__dynamic').text if item.find_elements(By.CLASS_NAME, 's-item__dynamic') else "Unknown Brand"
                seller = item.find_element(By.CLASS_NAME, 's-item__seller-info-text').text if item.find_elements(By.CLASS_NAME, 's-item__seller-info-text') else "Unknown Seller"
                ratings = item.find_element(By.CLASS_NAME, 'x-star-rating').text if item.find_elements(By.CLASS_NAME, 'x-star-rating') else "No Ratings"

                # Clean and format the extracted data
                brand = brand if brand in known_brands else "Unknown Brand"
                price = price.replace("$", "").replace(",", "").split(" to ")[0]  # Extract lowest price
                shipping_price = shipping_price.replace("$", "").replace(",", "").replace("Free Shipping", "0")
                ratings = ratings.split(" out of")[0] if "out of" in ratings else "No Ratings"

                # Append product details to the category-specific list
                category_records.append({
                    'event_type': 'view',  # Assign a default event type
                    'product_id': product_id,
                    'category_code': category,
                    'brand': brand,
                    'price': float(price) if price.isnumeric() else None,
                    'shipping_price': float(shipping_price) if shipping_price.isnumeric() else 0.0,
                    'seller': seller,
                    'ratings': float(ratings) if ratings.replace(".", "").isnumeric() else None,
                    'title': title
                })

                # Stop scraping if the category limit is reached
                if len(category_records) >= category_limit:
                    break
            
            except Exception as e:
                # Skip the item if any detail is not available
                continue
        
        if len(category_records) >= category_limit:
            print(f"Reached limit for {category}. Moving to the next category.")
            break  # Stop pagination for this category
        
        page += 1  # Move to the next page

    # Add category-specific records to the global list
    products.extend(category_records)

# Close the WebDriver
driver.quit()

# Convert to a DataFrame
df = pd.DataFrame(products)

# Save the DataFrame to a CSV file
df.to_csv('ebay_cleaned_dataset.csv', index=False)

print("Data successfully scraped and saved to 'ebay_cleaned_dataset.csv'")
# Out:
# Scraping data for category: smartphone
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=1
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=2
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=3
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=4
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=5
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=6
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=7
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=8
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=9
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=10
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=11
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=12
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=13
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=14
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=15
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=16
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=17
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=18
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=19
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=20
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=21
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=22
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=23
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=24
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=25
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=26
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=27
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=28
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=29
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=30
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=31
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=32
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=33
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=34
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=35
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=36
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=37
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=38
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=39
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=40
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=41
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=42
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=43
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=44
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=45
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=46
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=47
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=48
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=49
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=50
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=51
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=52
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=53
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=54
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=55
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=56
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=57
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=58
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=59
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=60
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=61
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=62
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=63
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=64
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=65
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=66
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=67
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=68
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=69
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=70
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=71
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=72
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=73
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=74
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=75
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=76
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=77
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=78
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=79
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=80
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=81
# Reached limit for smartphone. Moving to the next category.
# Scraping data for category: headphone
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=1
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=2
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=3
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=4
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=5
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=6
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=7
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=8
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=9
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=10
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=11
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=12
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=13
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=14
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=15
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=16
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=17
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=18
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=19
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=20
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=21
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=22
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=23
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=24
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=25
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=26
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=27
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=28
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=29
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=30
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=31
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=32
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=33
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=34
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=35
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=36
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=37
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=38
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=39
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=40
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=41
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=42
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=43
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=44
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=45
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=46
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=47
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=48
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=49
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=50
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=51
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=52
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=53
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=54
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=55
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=56
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=57
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=58
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=59
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=60
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=61
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=62
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=63
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=64
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=65
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=66
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=67
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=68
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=69
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=70
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=71
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=72
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=73
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=74
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=75
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=76
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=77
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=78
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=79
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=80
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=81
# Reached limit for headphone. Moving to the next category.
# Scraping data for category: tablet
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=1
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=2
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=3
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=4
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=5
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=6
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=7
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=8
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=9
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=10
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=11
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=12
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=13
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=14
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=15
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=16
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=17
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=18
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=19
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=20
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=21
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=22
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=23
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=24
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=25
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=26
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=27
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=28
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=29
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=30
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=31
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=32
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=33
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=34
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=35
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=36
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=37
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=38
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=39
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=40
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=41
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=42
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=43
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=44
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=45
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=46
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=47
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=48
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=49
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=50
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=51
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=52
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=53
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=54
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=55
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=56
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=57
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=58
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=59
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=60
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=61
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=62
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=63
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=64
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=65
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=66
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=67
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=68
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=69
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=70
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=71
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=72
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=73
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=74
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=75
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=76
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=77
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=78
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=79
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=80
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=81
# Reached limit for tablet. Moving to the next category.
# Data successfully scraped and saved to 'ebay_cleaned_dataset.csv'

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import pandas as pd

# Set up Selenium WebDriver
driver = webdriver.Chrome()  

categories = ['smartphone', 'headphone', 'tablet']
base_url = "https://www.ebay.com/sch/i.html?_nkw="
category_limit = 5000  # Limit per category

products = []

# List of known brands for cleaning
known_brands = ['xiaomi', 'apple', 'huawei', 'acme', 'samsung', 'oppo', 'hp',
       'steelseries', 'oneplus', 'irbis', 'vivo', 'nokia', 'meizu',
       'lenovo', 'honor', 'tp-link', 'elari', 'zte', 'harper', 'sony',
       'acer', 'lg', 'usams', 'bq', 'htc', 'blackberry', 'jbl', 'hyperx',
       'vertex', 'google', 'sennheiser', 'bose', 'huion', 'wacom',
       'kingston', 'prestigio', 'parrot', 'haier', 'razer', 'inoi',
       'jinga', 'doogee', 'nubia', 'creative', 'defender', 'beats',
       'texet', 'marshall', 'panasonic', 'olmio', 'microsoft', 'asus',
       'urbanears', 'awei', 'umi', 'fly', 'nexttab', 'jabra', 'koss',
       'olto', 'edifier', 'plantronics', 'beyerdynamic', 'tecno',
       'canyon', 'philips', 'trust', 'ritmix', 'genius', 'zalman', 'sven',
       'microlab', 'gionee', 'cnd', 'oukitel', 'orico', 'denn',
       'redragon', 'crown', 'audio-technica', 'krk', 'continent',
       'fender', 'wuw', 'leeco', 'inkax', 'micromax', 'xp-pen', 'pioneer',
       'presonus', 'hoco', 'global', 'marley', 'manhattan', 'fiio',
       'veho', 'bluedio', 'fostex', 'logitech', 'alctron', 'ipipoo',
       'qcyber', 'havit', 'leagoo', 'akg', 'ergo', 'joyroom', 'navitel',
       'jvc', 'yamaha', 'gamemax', 'shure', 'hercules', 'rapoo', 'roland',
       'intro', 'westone', 'rombica', 'nuforce', 'monster', 'vox',
       'magnat', 'soundking', 'gigabyte', 'remax', 'cowon', 'elenberg',
       'alesis', 'behringer', 'numark', 'hiper', 'acqua', 'superlux',
       'delux', 'ultrasone', 'msi', 'tascam', 'hifiman', 'dunu', 'meze',
       'g-cube', 'ark', 'samson', 'nomi', 'proel', 'siee', 'casio',
       'm-audio', 'tesoro', 'avermedia', 'celebrat', 'skullcandy',
       'gembird', 'sades', 'kalenji', 'borasco', 'nobby', 'gamdias',
       'motorola', 'cougar', 'aula', 'bravis', 'yison', 'mark', 'iwalk',
       'invotone', 'moxom']

# Iterate over categories to scrape data
for category in categories:
    print(f"Scraping data for category: {category}")
    page = 1
    category_records = []  # Temporary list for the current category
    
    while len(category_records) < category_limit:
        # Generate the URL for the current page and category
        url = f"{base_url}{category}&_pgn={page}"
        driver.get(url)
        print(f"Scraping URL: {url}")
        
        # Extract product details
        items = driver.find_elements(By.CLASS_NAME, 's-item')
        
        if not items:
            print(f"No more items found for {category}. Ending scraping for this category.")
            break
        
        for item in items:
            try:
                product_id = item.get_attribute('id')  # Retrieve Product ID
                title = item.find_element(By.CLASS_NAME, 's-item__title').text
                price = item.find_element(By.CLASS_NAME, 's-item__price').text if item.find_elements(By.CLASS_NAME, 's-item__price') else "0"
                shipping_price = item.find_element(By.CLASS_NAME, 's-item__shipping').text if item.find_elements(By.CLASS_NAME, 's-item__shipping') else "Free Shipping"
                brand = item.find_element(By.CLASS_NAME, 's-item__dynamic').text if item.find_elements(By.CLASS_NAME, 's-item__dynamic') else "Unknown Brand"
                seller = item.find_element(By.CLASS_NAME, 's-item__seller-info-text').text if item.find_elements(By.CLASS_NAME, 's-item__seller-info-text') else "Unknown Seller"
                ratings = item.find_element(By.CLASS_NAME, 'x-star-rating').text if item.find_elements(By.CLASS_NAME, 'x-star-rating') else "No Ratings"

                # Clean and format the extracted data
                brand = brand if brand.lower() in known_brands else "Unknown Brand"
                price = price.replace("$", "").replace(",", "").split(" to ")[0]  # Extract the lowest price if there's a range
                shipping_price = shipping_price.replace("$", "").replace(",", "").replace("Free Shipping", "0")
                ratings = ratings.split(" out of")[0] if "out of" in ratings else "No Ratings"

                # Append product details to the category-specific list
                category_records.append({
                    'event_type': 'view', 
                    'product_id': product_id,
                    'category_code': category,
                    'brand': brand,
                    'price': float(price) if price.replace(".", "").isdigit() else None,
                    'shipping_price': float(shipping_price) if shipping_price.replace(".", "").isdigit() else 0.0,
                    'seller': seller,
                    'ratings': float(ratings) if ratings.replace(".", "").isdigit() else None,
                    'title': title
                })

                # Stop scraping if the category limit is reached
                if len(category_records) >= category_limit:
                    break
            
            except Exception as e:
                # Skip the item if any detail is not available
                continue
        
        if len(category_records) >= category_limit:
            print(f"Reached limit for {category}. Moving to the next category.")
            break  # Stop pagination for this category
        
        page += 1  # Move to the next page

    # Add category-specific records to the global list
    products.extend(category_records)

# Close the WebDriver
driver.quit()

# Convert to a DataFrame
df = pd.DataFrame(products)

# Save the DataFrame to a CSV file
df.to_csv('ebay_cleaned_dataset.csv', index=False)

print("Data successfully scraped and saved to 'ebay_cleaned_dataset.csv'")
# Out:
# Scraping data for category: smartphone
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=1
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=2
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=3
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=4
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=5
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=6
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=7
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=8
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=9
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=10
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=11
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=12
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=13
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=14
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=15
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=16
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=17
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=18
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=19
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=20
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=21
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=22
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=23
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=24
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=25
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=26
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=27
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=28
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=29
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=30
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=31
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=32
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=33
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=34
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=35
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=36
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=37
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=38
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=39
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=40
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=41
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=42
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=43
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=44
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=45
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=46
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=47
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=48
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=49
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=50
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=51
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=52
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=53
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=54
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=55
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=56
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=57
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=58
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=59
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=60
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=61
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=62
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=63
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=64
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=65
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=66
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=67
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=68
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=69
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=70
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=71
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=72
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=73
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=74
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=75
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=76
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=77
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=78
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=79
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=80
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=smartphone&_pgn=81
# Reached limit for smartphone. Moving to the next category.
# Scraping data for category: headphone
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=1
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=2
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=3
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=4
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=5
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=6
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=7
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=8
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=9
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=10
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=11
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=12
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=13
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=14
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=15
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=16
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=17
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=18
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=19
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=20
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=21
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=22
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=23
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=24
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=25
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=26
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=27
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=28
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=29
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=30
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=31
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=32
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=33
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=34
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=35
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=36
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=37
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=38
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=39
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=40
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=41
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=42
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=43
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=44
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=45
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=46
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=47
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=48
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=49
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=50
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=51
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=52
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=53
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=54
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=55
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=56
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=57
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=58
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=59
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=60
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=61
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=62
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=63
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=64
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=65
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=66
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=67
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=68
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=69
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=70
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=71
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=72
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=73
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=74
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=75
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=76
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=77
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=78
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=79
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=80
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=headphone&_pgn=81
# Reached limit for headphone. Moving to the next category.
# Scraping data for category: tablet
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=1
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=2
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=3
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=4
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=5
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=6
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=7
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=8
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=9
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=10
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=11
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=12
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=13
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=14
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=15
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=16
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=17
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=18
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=19
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=20
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=21
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=22
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=23
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=24
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=25
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=26
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=27
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=28
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=29
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=30
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=31
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=32
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=33
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=34
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=35
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=36
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=37
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=38
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=39
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=40
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=41
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=42
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=43
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=44
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=45
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=46
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=47
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=48
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=49
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=50
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=51
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=52
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=53
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=54
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=55
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=56
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=57
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=58
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=59
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=60
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=61
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=62
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=63
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=64
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=65
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=66
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=67
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=68
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=69
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=70
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=71
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=72
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=73
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=74
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=75
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=76
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=77
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=78
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=79
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=80
# Scraping URL: https://www.ebay.com/sch/i.html?_nkw=tablet&_pgn=81
# Reached limit for tablet. Moving to the next category.
# Data successfully scraped and saved to 'ebay_cleaned_dataset.csv'

# %%
import pandas as pd
import re

# Load the dataset
df = pd.read_csv('ebay_cleaned_dataset.csv')

# Ensure the 'title' column is treated as strings and fill missing values with an empty string
df['title'] = df['title'].fillna("").astype(str)

# Function to extract the most probable brand from the title
def extract_brand(title):
    # Tokenize the title by splitting words
    words = re.findall(r'\b\w+\b', title)
    
    # Check for the most frequently occurring word in the dataset's 'title' column
    possible_brands = set(df['title'].str.extractall(r'\b(\w+)\b')[0].value_counts().index)
    
    # Find the first word in the title that matches any possible brand
    for word in words:
        if word in possible_brands:
            return word.capitalize()
    return "Unknown Brand"

# Apply the function to extract brand dynamically
df['brand'] = df['title'].apply(extract_brand)

# Save the updated DataFrame
df.to_csv('ebay_cleaned_with_extracted_brands.csv', index=False)

print("Brand names extracted and saved to 'ebay_cleaned_with_extracted_brands.csv'")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 25
#      22     return "Unknown Brand"
#      24 # Apply the function to extract brand dynamically
# ---> 25 df['brand'] = df['title'].apply(extract_brand)
#      27 # Save the updated DataFrame
#      28 df.to_csv('ebay_cleaned_with_extracted_brands.csv', index=False)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/series.py:4917, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
# -> 4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
#    4924     ).apply()
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[5], line 16, in extract_brand(title)
#      13 words = re.findall(r'\b\w+\b', title)
#      15 # Check for the most frequently occurring word in the dataset's 'title' column
# ---> 16 possible_brands = set(df['title'].str.extractall(r'\b(\w+)\b')[0].value_counts().index)
#      18 # Find the first word in the title that matches any possible brand
#      19 for word in words:
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/strings/accessor.py:137, in forbid_nonstring_types.<locals>._forbid_nonstring_types.<locals>.wrapper(self, *args, **kwargs)
#     132     msg = (
#     133         f"Cannot use .str.{func_name} with values of "
#     134         f"inferred dtype '{self._inferred_dtype}'."
#     135     )
#     136     raise TypeError(msg)
# --> 137 return func(self, *args, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/strings/accessor.py:2853, in StringMethods.extractall(self, pat, flags)
#    2779 r"""
#    2780 Extract capture groups in the regex `pat` as columns in DataFrame.
#    2781
#    (...)
#    2850 C 0        NaN     1
#    2851 """
#    2852 # TODO: dispatch
# -> 2853 return str_extractall(self._orig, pat, flags)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/strings/accessor.py:3533, in str_extractall(arr, pat, flags)
#    3531             match_list.append(na_tuple)
#    3532             result_key = tuple(subject_key + (match_i,))
# -> 3533             index_list.append(result_key)
#    3535 from pandas import MultiIndex
#    3537 index = MultiIndex.from_tuples(index_list, names=arr.index.names + ["match"])
#
# KeyboardInterrupt:
